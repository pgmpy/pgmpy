# %%
from pgmpy.models import DynamicBayesianNetwork as DBN
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import DBNInference
# Out:
# C:\Users\aggra\pgmpy\pgmpy\factors\base.py:80: SyntaxWarning: invalid escape sequence '\s'
#   """
# C:\Users\aggra\pgmpy\pgmpy\models\DiscreteMarkovNetwork.py:625: SyntaxWarning: invalid escape sequence '\p'
#   """
# C:\Users\aggra\pgmpy\pgmpy\models\DiscreteMarkovNetwork.py:739: SyntaxWarning: invalid escape sequence '\s'
#   """
# C:\Users\aggra\pgmpy\pgmpy\models\FactorGraph.py:404: SyntaxWarning: invalid escape sequence '\s'
#   """
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pgmpy.models import DynamicBayesianNetwork as DBN
#       2 from pgmpy.factors.discrete import TabularCPD
#       3 from pgmpy.inference import DBNInference
#
# File ~\pgmpy\pgmpy\models\__init__.py:7
#       5 from .DynamicBayesianNetwork import DynamicBayesianNetwork
#       6 from .FactorGraph import FactorGraph
# ----> 7 from .FunctionalBayesianNetwork import FunctionalBayesianNetwork
#       8 from .JunctionTree import JunctionTree
#       9 from .LinearGaussianBayesianNetwork import LinearGaussianBayesianNetwork
#
# File ~\pgmpy\pgmpy\models\FunctionalBayesianNetwork.py:4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import pyro
#       5 import torch
#       7 from pgmpy import config
#
# ModuleNotFoundError: No module named 'pyro'

# %%
dbn = DBN()
dbn.add_edges_from([(("A", 0), ("B", 0)), (("A", 0), ("A", 1)), (("B", 0), ("B", 1))])
