# %% [markdown]
# # Structure Learning in Bayesian Networks

# %% [markdown]
# In this notebook, we show a few examples of Causal Discovery or Structure Learning in pgmpy. pgmpy currently has the following algorithm for causal discovery:
#
# 1. **PC**: Has $3$ variants original, stable, and parallel. PC is a constraint-based algorithm that utilizes Conditional Independence tests to construct the model.
# 2. **Hill-Climb Search**: Hill-Climb Search is a greedy optimization-based algorithm that makes iterative local changes to the model structure such that it improves the overall score of the model.
# 3. **Exhaustive Search**: Exhaustive search iterates over all possible network structures on the given variables to find the most optimal one. As it tries to enumerate all possible network structures, it is intractable when the number of variables in the data is large.
# 4. **Greedy Equivalence Search**: Greedy Equivalence Search is a greedy optimization-based algorithm that makes changes in three phases - edge addition, edge removal and edge flipping to improve the overall score of the model.
# 5. **Max-Min Hill Climb Search**: The max-min Hill Climb search algorithm combines score based and constraint based approaches to estimate the final graph.
# 6. **Tree Search**: Tree Search estimator is for learning tree related graph structures. Supported algorithms are Chow-Liu and Tree-augmented naive bayes (TAN).
#
# The following Conditional Independence Tests are available to use with the PC algorithm:
# 1. **Pillai**: Test for mixed data based on residualization approach. It is a generalization of Pearsonr to mixed data.
# 1. **Chi-Square test**: Works only for discrete data.
# 2. **Pearsonr**: A partial correlation-based test. Works for Gaussian continuous variables.
# 3. **G-squared**: Works only for discrete data.
# 4. **Log-likelihood**: Works only for discrete data.
#
# For Hill-Climb and Exhausitive Search the following scoring methods can be used:
# 1. **BIC Score**
# 2. **AIC Score**
# 3. **K2 Score**
# 4. **BDeU Score**
# 5. **BDs Score**

# %% [markdown]
# ## Import libraries and define f2-score

# %%
from sklearn.metrics import f1_score
from pgmpy.estimators import PC, HillClimbSearch, ExpertKnowledge, K2
from pgmpy.utils import get_example_model

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Funtion to evaluate the learned model structures.
def get_f1_score(estimated_model, true_model):
    nodes = estimated_model.nodes()
    est_adj = nx.to_numpy_array(
        estimated_model.to_undirected(), nodelist=nodes, weight=None
    )
    true_adj = nx.to_numpy_array(
        true_model.to_undirected(), nodelist=nodes, weight=None
    )

    f1 = f1_score(np.ravel(true_adj), np.ravel(est_adj))
    print("F1-score for the model skeleton: ", f1)

# %% [markdown]
# ## Simulate data and learn structure using PC

# %%
cancer_model = get_example_model("cancer")
cancer_samples = cancer_model.simulate(int(1e4))
cancer_samples.head()
# Out:
# Generating for node: Dyspnoea: 100%|██████████| 5/5 [00:00<00:00, 127.11it/s]
#        Xray Smoker Dyspnoea Pollution Cancer
# 0  negative  False    False       low  False
# 1  positive  False     True       low  False
# 2  negative   True     True       low  False
# 3  negative  False    False       low  False
# 4  positive   True    False       low  False

# %%
est = PC(data=cancer_samples)
estimated_model = est.estimate(variant="stable", max_cond_vars=4)

plt.figure(figsize=(8, 6))
nx.draw(estimated_model, with_labels=True , font_size=10, node_size=100, node_color='#AFCBFF', arrowsize=8 )
plt.show()
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Xray': 'C', 'Smoker': 'C', 'Dyspnoea': 'C', 'Pollution': 'C', 'Cancer': 'C'}
# Working for n conditional variables: 5: 100%|██████████| 5/5 [00:00<00:00, 12.65it/s]

# %% [markdown]
# As seen, the samples are not enough to correctly predict the [graph structure](https://www.bnlearn.com/bnrepository/discrete-small.html#cancer). We can combine PC with expert knowledge to get a more accurate learned graph.

# %%
background = ExpertKnowledge( 
            temporal_order=[["Pollution", "Smoker", "Cancer"], ["Dyspnoea", "Xray"]],
            max_cond_vars=4,
        )

est = PC(data=cancer_samples)
estimated_model = est.estimate(variant="stable", max_cond_vars=4,  expert_knowledge=background)

plt.figure(figsize=(8, 6))
nx.draw(estimated_model, with_labels=True , font_size=10, node_size=100, node_color='#AFCBFF', arrowsize=8 )
plt.show()
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Xray': 'C', 'Smoker': 'C', 'Dyspnoea': 'C', 'Pollution': 'C', 'Cancer': 'C'}
# Working for n conditional variables: 5: 100%|██████████| 5/5 [00:00<00:00, 17.01it/s]

# %% [markdown]
# ## Simulate data and learn structure using Hill-Climb Search

# %%
alarm_model = get_example_model("alarm")
alarm_samples = alarm_model.simulate(int(1e3))
alarm_samples.head()
# Out:
# ...
# Generating for node: BP: 100%|██████████| 37/37 [00:00<00:00, 205.74it/s]
#   PULMEMBOLUS  HRBP STROKEVOLUME    PCWP   PRESS ERRCAUTER INSUFFANESTH  \
# 0       FALSE  HIGH       NORMAL  NORMAL    HIGH     FALSE        FALSE
# 1       FALSE  HIGH       NORMAL  NORMAL  NORMAL     FALSE        FALSE
# 2       FALSE  HIGH       NORMAL  NORMAL  NORMAL      TRUE         TRUE
# 3       FALSE  HIGH       NORMAL    HIGH    HIGH     FALSE        FALSE
# 4       FALSE   LOW       NORMAL  NORMAL     LOW     FALSE        FALSE
#
#   ANAPHYLAXIS    FIO2 LVFAILURE  ... ERRLOWOUTPUT EXPCO2 INTUBATION CATECHOL  \
# 0       FALSE  NORMAL     FALSE  ...        FALSE    LOW     NORMAL     HIGH
# 1       FALSE  NORMAL     FALSE  ...        FALSE    LOW     NORMAL     HIGH
# 2       FALSE  NORMAL     FALSE  ...        FALSE    LOW     NORMAL     HIGH
# 3       FALSE  NORMAL     FALSE  ...        FALSE    LOW     NORMAL     HIGH
# ...

# %%
scoring_method = K2(data=alarm_samples)
est = HillClimbSearch(data=alarm_samples)
estimated_model = est.estimate(
    scoring_method=scoring_method, max_indegree=4, max_iter=int(1e4)
)
get_f1_score(estimated_model, alarm_model)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'PULMEMBOLUS': 'C', 'HRBP': 'C', 'STROKEVOLUME': 'C', 'PCWP': 'C', 'PRESS': 'C', 'ERRCAUTER': 'C', 'INSUFFANESTH': 'C', 'ANAPHYLAXIS': 'C', 'FIO2': 'C', 'LVFAILURE': 'C', 'CVP': 'C', 'VENTALV': 'C', 'HREKG': 'C', 'DISCONNECT': 'C', 'BP': 'C', 'KINKEDTUBE': 'C', 'TPR': 'C', 'SAO2': 'C', 'PAP': 'C', 'HISTORY': 'C', 'LVEDVOLUME': 'C', 'PVSAT': 'C', 'SHUNT': 'C', 'MINVOL': 'C', 'VENTLUNG': 'C', 'VENTMACH': 'C', 'HR': 'C', 'ERRLOWOUTPUT': 'C', 'EXPCO2': 'C', 'INTUBATION': 'C', 'CATECHOL': 'C', 'CO': 'C', 'MINVOLSET': 'C', 'HRSAT': 'C', 'VENTTUBE': 'C', 'HYPOVOLEMIA': 'C', 'ARTCO2': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
# ...
